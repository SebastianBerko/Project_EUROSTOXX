# %%
# !pip install yahoo_fin
# Out:
# Requirement already satisfied: yahoo_fin in /Users/jk/anaconda3/lib/python3.8/site-packages (0.8.9.1)
# Requirement already satisfied: requests in /Users/jk/anaconda3/lib/python3.8/site-packages (from yahoo_fin) (2.25.1)
# Requirement already satisfied: pandas in /Users/jk/anaconda3/lib/python3.8/site-packages (from yahoo_fin) (1.2.4)
# Requirement already satisfied: feedparser in /Users/jk/anaconda3/lib/python3.8/site-packages (from yahoo_fin) (6.0.8)
# Requirement already satisfied: requests-html in /Users/jk/anaconda3/lib/python3.8/site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: sgmllib3k in /Users/jk/anaconda3/lib/python3.8/site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/jk/anaconda3/lib/python3.8/site-packages (from pandas->yahoo_fin) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/jk/anaconda3/lib/python3.8/site-packages (from pandas->yahoo_fin) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/jk/anaconda3/lib/python3.8/site-packages (from pandas->yahoo_fin) (1.20.1)
# Requirement already satisfied: six>=1.5 in /Users/jk/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/jk/anaconda3/lib/python3.8/site-packages (from requests->yahoo_fin) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/jk/anaconda3/lib/python3.8/site-packages (from requests->yahoo_fin) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jk/anaconda3/lib/python3.8/site-packages (from requests->yahoo_fin) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jk/anaconda3/lib/python3.8/site-packages (from requests->yahoo_fin) (2021.10.8)
# Requirement already satisfied: pyquery in /Users/jk/anaconda3/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: w3lib in /Users/jk/anaconda3/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.22.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in /Users/jk/anaconda3/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: parse in /Users/jk/anaconda3/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: fake-useragent in /Users/jk/anaconda3/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.1.11)
# Requirement already satisfied: bs4 in /Users/jk/anaconda3/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /Users/jk/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/jk/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.10.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Users/jk/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.59.0)
# Requirement already satisfied: websockets<11.0,>=10.0 in /Users/jk/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Users/jk/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: zipp>=0.5 in /Users/jk/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.4.1)
# Requirement already satisfied: beautifulsoup4 in /Users/jk/anaconda3/lib/python3.8/site-packages (from bs4->requests-html->yahoo_fin) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/jk/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.2.1)
# Requirement already satisfied: cssselect>0.7.9 in /Users/jk/anaconda3/lib/python3.8/site-packages (from pyquery->requests-html->yahoo_fin) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in /Users/jk/anaconda3/lib/python3.8/site-packages (from pyquery->requests-html->yahoo_fin) (4.6.3)

# %%
# !pip install requests_html
# Out:
# Requirement already satisfied: requests_html in ./opt/anaconda3/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (2.25.1)
# Requirement already satisfied: w3lib in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (1.22.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (0.2.6)
# Requirement already satisfied: bs4 in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (0.0.1)
# Requirement already satisfied: pyquery in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (1.4.3)
# Requirement already satisfied: parse in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (1.19.0)
# Requirement already satisfied: fake-useragent in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (0.1.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (4.59.0)
# Requirement already satisfied: importlib-metadata>=1.4 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (3.10.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.4)
# Requirement already satisfied: websockets<10.0,>=9.1 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (9.1)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: zipp>=0.5 in ./opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.4.1)
# Requirement already satisfied: beautifulsoup4 in ./opt/anaconda3/lib/python3.8/site-packages (from bs4->requests_html) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in ./opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->bs4->requests_html) (2.2.1)
# Requirement already satisfied: lxml>=2.1 in ./opt/anaconda3/lib/python3.8/site-packages (from pyquery->requests_html) (4.6.3)
# Requirement already satisfied: cssselect>0.7.9 in ./opt/anaconda3/lib/python3.8/site-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->requests_html) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->requests_html) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->requests_html) (2.10)
# Requirement already satisfied: six>=1.4.1 in ./opt/anaconda3/lib/python3.8/site-packages (from w3lib->requests_html) (1.15.0)

# %% [markdown]
# **We found the below method of downloading Yahoo Finance information from the statistics page on the internet and it seems to work. Alternativly, one could go into each of the ticker codes of Yahoo Finance page**

# %%
import yahoo_fin.stock_info as si #Get data
import pandas as pd #Data manipulation
from tqdm import tqdm #Make a progress bar because that's cool...
import requests # to get data
from bs4 import BeautifulSoup # to parse external data
from requests_html import HTMLSession
import matplotlib.pyplot as plt

# %%
#Scraper of EUROSTOXX50 index
scrEURSTX = requests.get('https://en.wikipedia.org/wiki/EURO_STOXX_50')
soupEURSTX = BeautifulSoup(scrEURSTX.text, 'lxml')
tableEURSTX = soupEURSTX.find(text="Ticker").find_parent("table").find('tbody').findAll('tr')[1:]
EURSTX_companies = pd.DataFrame()
for row in tableEURSTX:
    ticker = row.findAll('td')[0].text.strip()
    title = row.findAll('td')[2].text.strip()
    industry = row.findAll('td')[5].text.strip()
    row_ = pd.Series({"Ticker":ticker, "Name": title, "Industry":industry})
    EURSTX_companies = pd.concat([EURSTX_companies, row_], axis=1, ignore_index = True)
    
EURSTX_companies = EURSTX_companies.T
EURSTX_ticker = EURSTX_companies.iloc[:,0]
EURSTX_companies
EURSTX_ticker
# Out:
# 0       ADS.DE
# 1     ADYEN.AS
# 2        AD.AS
# 3        AI.PA
# 4       AIR.PA
# 5       ALV.DE
# 6       ABI.BR
# 7      ASML.AS
# 8        CS.PA
# 9       BAS.DE
# 10     BAYN.DE
# 11     BBVA.MC
# 12      SAN.MC
# 13      BMW.DE
# 14      BNP.PA
# 15      CRG.IR
# 16      DAI.DE
# 17       BN.PA
# 18      DB1.DE
# 19      DPW.DE
# 20      DTE.DE
# 21     ENEL.MI
# 22      ENI.MI
# 23       EL.PA
# 24     FLTR.IR
# 25      IBE.MC
# 26      ITX.MC
# 27      IFX.DE
# 28     INGA.AS
# 29      ISP.MI
# 30      KER.PA
# 31    KNEBV.HE
# 32       OR.PA
# 33      LIN.DE
# 34       MC.PA
# 35     MUV2.DE
# 36       RI.PA
# 37     PHIA.AS
# 38      PRX.AS
# 39      SAF.PA
# 40      SAN.PA
# 41      SAP.DE
# 42       SU.PA
# 43      SIE.DE
# 44     STLA.MI
# 45      TTE.PA
# 46      UMG.AS
# 47       DG.PA
# 48      VOW.DE
# 49      VNA.DE
# Name: Ticker, dtype: object

# %%
companies = ["ADS.DE", "ADYEN.AS", "AD.AS", "AI.PA", "AIR.PA", "ALV.DE", "ABI.BR", "ASML.AS", "CS.PA", "BAS.DE", "BAYN.DE", "BBVA.MC", "SAN.MC", "BMW.DE", "BNP.PA", "CRG.IR", "DAI.DE", "BN.PA", "DB1.DE", "DPW.DE", "DTE.DE", "ENEL.MI", "ENI.MI", "CS.PA", "EL.PA", "FLTR.IR", "IBE.MC", "ITX.MC", "IFX.DE", "INGA.AS", "ISP.MI", "KER.PA", "KNEBV.HE", "OR.PA", "LIN.DE", "MC.PA", "MUV2.DE", "RI.PA", "PHIA.AS", "PRX.AS", "SAF.PA", "SAN.PA", "SAP.DE", "SU.PA", "SIE.DE", "STLA.MI", "TTE.PA", "UMG.AS", "DG.PA", "VOW.DE", "VNA.DE"]

# %%
ticker_stats = {}
for ticker in companies:
    temp = si.get_stats_valuation(ticker)
    temp = temp.iloc[:,:2]
    #temp.iloc[:,:2] creates to columns
    temp.columns = ["Attribute", "Recent"]
    #We want the name of the data and then the data itself
 
    ticker_stats[ticker] = temp
    #Where to get


# combine all the stats valuation tables into a single data frame
df1 = pd.concat(ticker_stats)
#Adding the data together by concatenating.
df1 = df1.reset_index()
#Adding a sequantial index and using the Ticker as the index 

del df1["level_1"]
#dropping level 1 of the multi-index

# update column names
df1.columns = ["Ticker", "Attribute", "Recent"]

# Same, but for more data
ticker_extra_stats = {}
for ticker in tqdm(companies):
    ticker_extra_stats[ticker] = si.get_stats(ticker)
    

df2 = pd.concat(ticker_extra_stats)

df2 = df2.reset_index()

del df2["level_1"]

df2.columns = ["Ticker", "Attribute", "Value"]
# Out:
# 100%|██████████| 51/51 [00:47<00:00,  1.07it/s]

# %%
print(df1)
# Out:
#      Ticker                  Attribute  Recent
# 0    ADS.DE      Market Cap (intraday)  46.54B
# 1    ADS.DE           Enterprise Value  47.38B
# 2    ADS.DE               Trailing P/E   32.69
# 3    ADS.DE                Forward P/E   24.94
# 4    ADS.DE  PEG Ratio (5 yr expected)    0.59
# ..      ...                        ...     ...
# 445  VNA.DE  PEG Ratio (5 yr expected)     NaN
# 446  VNA.DE          Price/Sales (ttm)    9.45
# 447  VNA.DE           Price/Book (mrq)    1.41
# 448  VNA.DE   Enterprise Value/Revenue   11.12
# 449  VNA.DE    Enterprise Value/EBITDA    4.13
#
# [450 rows x 3 columns]

# %%
print(df2)
# Out:
#       Ticker                     Attribute    Value
# 0     ADS.DE             Beta (5Y Monthly)     0.87
# 1     ADS.DE              52-Week Change 3  -13.02%
# 2     ADS.DE       S&P500 52-Week Change 3   14.94%
# 3     ADS.DE                52 Week High 3   336.25
# 4     ADS.DE                 52 Week Low 3   231.55
# ...      ...                           ...      ...
# 2545  VNA.DE       Total Debt/Equity (mrq)   162.57
# 2546  VNA.DE           Current Ratio (mrq)     0.39
# 2547  VNA.DE    Book Value Per Share (mrq)    47.85
# 2548  VNA.DE     Operating Cash Flow (ttm)    1.44B
# 2549  VNA.DE  Levered Free Cash Flow (ttm)    8.66B
#
# [2550 rows x 3 columns]

# %% [markdown]
# **Now we simply need to format the data into a format which is usable in relation to the graph we wish to display:**
#
# At the moment, we have the data in very few columns and many rows. Essentially, every ticker is repeated for every attribute. We now wish to change this such that the ticker is displayed once in a row and all the attributed on a column name.

# %%
# Convert from long dataframe to wide dataframe using the pivot() method.
df1_wide = df1.pivot(index = "Ticker", columns="Attribute", values="Recent")
df2_wide = df2.pivot(index = "Ticker", columns="Attribute", values="Value")

# %%
print(df1_wide)
# Out:
# Attribute Enterprise Value Enterprise Value/EBITDA Enterprise Value/Revenue  \
# Ticker
# ABI.BR                 NaN                     NaN                      NaN
# AD.AS                  NaN                     NaN                      NaN
# ADS.DE              47.38B                   14.17                     2.09
# ADYEN.AS            46.92B                   94.14                    10.12
# AI.PA               84.75B                   14.32                     4.02
# AIR.PA              84.00B                   10.68                     1.53
# ALV.DE             106.40B                     NaN                     0.94
# ASML.AS            239.76B                   34.22                    12.88
# BAS.DE              78.66B                    6.87                     1.05
# BAYN.DE             81.70B                   11.26                     1.90
# BBVA.MC                NaN                     NaN                      NaN
# BMW.DE             129.87B                    5.86                     1.16
# BN.PA               46.02B                   12.87                     1.98
# BNP.PA                 NaN                     NaN                      NaN
# CRG.IR              40.73B                    9.40                     1.38
# CS.PA                  NaN                     NaN                      NaN
# DAI.DE             177.90B                    7.27                     1.06
# DB1.DE             -57.81B                  -28.94                   -13.83
# DG.PA               76.03B                   10.94                     1.58
# DPW.DE              78.83B                    6.88                     1.02
# DTE.DE             217.74B                    5.03                     2.03
# EL.PA               77.79B                   18.71                     4.58
# ENEL.MI             92.90B                    6.20                     1.19
# ENI.MI                 NaN                     NaN                      NaN
# FLTR.IR             25.31B                   24.68                     4.27
# IBE.MC                 NaN                     NaN                      NaN
# IFX.DE              48.28B                   16.16                     4.37
# INGA.AS                NaN                     NaN                      NaN
# ISP.MI                 NaN                     NaN                      NaN
# ITX.MC              76.71B                   11.75                     2.99
# KER.PA              86.52B                   14.07                     5.49
# KNEBV.HE            26.71B                   16.74                     2.58
# LIN.DE             152.08B                   15.68                     5.11
# MC.PA              387.95B                   19.34                     7.06
# MUV2.DE             37.41B                     NaN                     0.55
# OR.PA              197.07B                   25.44                     6.54
# PHIA.AS             30.18B                   14.94                     1.76
# PRX.AS             219.41B                   10.62                    36.52
# RI.PA               57.36B                   21.79                     6.50
# SAF.PA              48.65B                   13.44                     3.36
# SAN.MC                 NaN                     NaN                      NaN
# SAN.PA             126.27B                   11.34                     3.36
# SAP.DE             138.28B                   29.67                     4.97
# SIE.DE             146.43B                   13.06                     2.35
# STLA.MI             44.25B                    2.69                     0.35
# SU.PA               90.92B                   17.49                     3.32
# TTE.PA             159.86B                    4.82                     0.99
# UMG.AS              42.21B                   28.68                     5.41
# VNA.DE              35.84B                    4.13                    11.12
# VOW.DE             230.05B                    4.33                     0.91
#
# Attribute Forward P/E Market Cap (intraday) PEG Ratio (5 yr expected)  \
# Ticker
# ABI.BR            NaN                   NaN                      6.35
# AD.AS             NaN                   NaN                       NaN
# ADS.DE          24.94                46.54B                      0.59
# ADYEN.AS        79.37                50.12B                       NaN
# AI.PA           23.98                71.58B                      2.38
# AIR.PA          21.46                87.73B                      1.11
# ALV.DE          10.21                92.09B                      1.09
# ASML.AS         33.67               243.27B                      2.49
# BAS.DE          11.32                61.98B                      0.79
# BAYN.DE          7.86                52.03B                      3.01
# BBVA.MC          7.68                36.91B                      0.44
# BMW.DE           6.23                60.94B                      0.25
# BN.PA           16.89                35.16B                      4.80
# BNP.PA           9.51                78.49B                      1.01
# CRG.IR          14.47                35.29B                      1.22
# CS.PA             NaN                   NaN                       NaN
# DAI.DE           7.17                75.06B                      0.46
# DB1.DE          21.51                28.33B                      2.99
# DG.PA           15.58                55.29B                      0.59
# DPW.DE          13.72                66.28B                      1.19
# DTE.DE          13.50                86.32B                      1.29
# EL.PA           27.62                75.82B                       NaN
# ENEL.MI         12.11                68.89B                      1.74
# ENI.MI            NaN                   NaN                       NaN
# FLTR.IR         31.85                22.11B                       NaN
# IBE.MC            NaN                   NaN                       NaN
# IFX.DE          21.37                45.29B                      1.23
# INGA.AS         10.20                49.92B                      0.61
# ISP.MI            NaN                   NaN                       NaN
# ITX.MC          19.80                80.43B                      0.54
# KER.PA          21.93                81.81B                      1.40
# KNEBV.HE        28.01                29.05B                      4.25
# LIN.DE          26.53               141.44B                      2.15
# MC.PA           27.32               358.12B                      1.17
# MUV2.DE         12.08                38.38B                      0.52
# OR.PA           40.32               199.44B                      4.08
# PHIA.AS         17.06                25.51B                      3.13
# PRX.AS          12.92               221.89B                       NaN
# RI.PA           26.53                49.84B                      2.24
# SAF.PA          28.90                45.85B                      0.89
# SAN.MC           6.32                56.29B                       NaN
# SAN.PA          12.55               114.34B                      3.50
# SAP.DE          19.34               132.23B                      2.14
# SIE.DE          16.10               109.78B                      2.47
# STLA.MI          4.48                54.56B                      0.27
# SU.PA           22.57                83.06B                      2.06
# TTE.PA           9.35               129.41B                       NaN
# UMG.AS          27.25                39.56B                       NaN
# VNA.DE          19.57                39.17B                       NaN
# VOW.DE           7.86               112.25B                      0.79
#
# Attribute Price/Book (mrq) Price/Sales (ttm) Trailing P/E
# Ticker
# ABI.BR                 NaN               NaN        41.64
# AD.AS                  NaN               NaN          NaN
# ADS.DE                6.04              2.09        32.69
# ADYEN.AS             34.89             10.70       134.80
# AI.PA                 3.75              3.40        27.61
# AIR.PA                9.98              1.60        20.95
# ALV.DE                1.13              0.80        10.84
# ASML.AS              23.00             12.65        40.01
# BAS.DE                1.57              0.83        11.54
# BAYN.DE               1.67              1.21       230.26
# BBVA.MC               0.82              1.57        10.35
# BMW.DE                0.86              0.55         5.24
# BN.PA                 2.12              1.54        17.95
# BNP.PA                0.68              1.41         9.54
# CRG.IR                2.05              1.39        27.12
# CS.PA                  NaN               NaN          NaN
# DAI.DE                1.02              0.45         6.49
# DB1.DE                3.90              6.78        24.46
# DG.PA                 2.59              1.16        24.89
# DPW.DE                3.83              0.87        13.86
# DTE.DE                2.10              0.77        15.18
# EL.PA                 2.24              4.48        56.18
# ENEL.MI               2.26              0.91        32.28
# ENI.MI                 NaN               NaN         18.7
# FLTR.IR               1.72              2.99          NaN
# IBE.MC                 NaN               NaN          NaN
# IFX.DE                3.97              4.10        39.55
# INGA.AS               0.90              2.83        11.49
# ISP.MI                 NaN               NaN          NaN
# ITX.MC                5.39              3.14        27.38
# KER.PA                6.54              5.22        24.68
# KNEBV.HE              9.15              2.76        28.61
# LIN.DE                3.60              5.49        45.85
# MC.PA                 8.70              6.53        37.92
# MUV2.DE               1.28              0.57        16.90
# OR.PA                 6.73              6.95        51.03
# PHIA.AS               1.74              1.53        43.04
# PRX.AS                4.59             21.27         6.30
# RI.PA                 3.36              5.69        38.48
# SAF.PA                3.52              3.27        34.32
# SAN.MC                0.65              1.27         7.57
# SAN.PA                1.81              3.06        19.84
# SAP.DE                3.66              4.62        23.92
# SIE.DE                2.47              1.78        21.79
# STLA.MI               1.17              0.33         4.87
# SU.PA                 3.83              3.05        28.68
# TTE.PA                1.33              0.95        13.83
# UMG.AS               26.61              5.07        36.98
# VNA.DE                1.41              9.45         5.84
# VOW.DE                0.91              0.50         7.17

# %%
print(df2_wide)
# Out:
# Attribute % Held by Insiders 1 % Held by Institutions 1  \
# Ticker
# ABI.BR                  48.74%                   14.19%
# AD.AS                    0.05%                   52.47%
# ADS.DE                  10.29%                   53.19%
# ADYEN.AS                23.65%                   62.53%
# AI.PA                    2.61%                   29.60%
# AIR.PA                  25.84%                   31.47%
# ALV.DE                   0.00%                   39.94%
# ASML.AS                  0.01%                   57.08%
# BAS.DE                   0.00%                   28.81%
# BAYN.DE                  0.00%                   38.21%
# BBVA.MC                  0.02%                   34.30%
# BMW.DE                  46.74%                   21.57%
# BN.PA                    2.65%                   55.72%
# BNP.PA                  13.20%                   51.26%
# CRG.IR                   0.02%                   52.93%
# CS.PA                   18.80%                   44.53%
# DAI.DE                  18.35%                   35.41%
# DB1.DE                   0.00%                   60.26%
# DG.PA                    8.94%                   38.44%
# DPW.DE                  20.49%                   35.02%
# DTE.DE                  18.36%                   43.04%
# EL.PA                   35.99%                   26.44%
# ENEL.MI                 23.58%                   34.84%
# ENI.MI                  30.30%                   16.77%
# FLTR.IR                  3.18%                   61.40%
# IBE.MC                   0.21%                   42.13%
# IFX.DE                   0.00%                   58.18%
# INGA.AS                  0.00%                   52.39%
# ISP.MI                   4.73%                   40.29%
# ITX.MC                  64.35%                   15.49%
# KER.PA                  41.71%                   25.93%
# KNEBV.HE                27.81%                   36.55%
# LIN.DE                   0.20%                   79.85%
# MC.PA                   47.48%                   21.26%
# MUV2.DE                  0.03%                   44.06%
# OR.PA                   54.18%                   14.88%
# PHIA.AS                  0.09%                   54.44%
# PRX.AS                  57.63%                   15.12%
# RI.PA                   24.56%                   50.28%
# SAF.PA                  18.45%                   38.56%
# SAN.MC                   0.73%                   30.89%
# SAN.PA                  11.15%                   54.33%
# SAP.DE                  11.09%                   35.72%
# SIE.DE                   6.00%                   35.24%
# STLA.MI                 26.01%                   52.84%
# SU.PA                    3.77%                   56.82%
# TTE.PA                   6.41%                   48.40%
# UMG.AS                  48.05%                   24.10%
# VNA.DE                   0.00%                   53.05%
# VOW.DE                  73.31%                   18.68%
#
# Attribute 200-Day Moving Average 3 5 Year Average Dividend Yield 4  \
# Ticker
# ABI.BR                       54.99                            2.96
# AD.AS                        27.55                            3.45
# ADS.DE                      282.66                             NaN
# ADYEN.AS                   2268.30                             NaN
# AI.PA                       147.70                            2.17
# AIR.PA                      110.59                             NaN
# ALV.DE                      207.16                            4.52
# ASML.AS                     645.08                            0.82
# BAS.DE                       65.07                            4.76
# BAYN.DE                      49.59                            3.94
# BBVA.MC                       5.43                            4.86
# BMW.DE                       87.38                            4.28
# BN.PA                        58.10                             NaN
# BNP.PA                       56.43                             NaN
# CRG.IR                       43.23                            2.38
# CS.PA                        24.15                             NaN
# DAI.DE                       75.66                            5.00
# DB1.DE                      144.67                            2.17
# DG.PA                        91.65                            2.74
# DPW.DE                       55.64                             NaN
# DTE.DE                       17.06                             NaN
# EL.PA                       165.43                             NaN
# ENEL.MI                       7.42                            4.45
# ENI.MI                       11.30                            6.13
# FLTR.IR                     151.57                             NaN
# IBE.MC                       10.23                            4.25
# IFX.DE                       36.30                            1.14
# INGA.AS                      11.95                             NaN
# ISP.MI                      2.3876                             NaN
# ITX.MC                       29.93                            1.80
# KER.PA                      697.93                            1.52
# KNEBV.HE                     64.46                            3.19
# LIN.DE                      266.78                             NaN
# MC.PA                       672.25                            1.47
# MUV2.DE                     246.38                            4.34
# OR.PA                       387.40                             NaN
# PHIA.AS                      38.37                             NaN
# PRX.AS                       76.22                             NaN
# RI.PA                       191.81                            1.68
# SAF.PA                      112.92                             NaN
# SAN.MC                      3.1516                             NaN
# SAN.PA                       87.08                            3.83
# SAP.DE                      120.65                            1.40
# SIE.DE                      141.71                            3.30
# STLA.MI                      16.78                             NaN
# SU.PA                       147.76                            2.67
# TTE.PA                       41.29                            6.06
# UMG.AS                       24.44                             NaN
# VNA.DE                       52.89                            3.02
# VOW.DE                      276.72                             NaN
#
# Attribute 50-Day Moving Average 3 52 Week High 3 52 Week Low 3  \
# Ticker
# ABI.BR                      54.29          65.86         46.66
# AD.AS                       29.94          31.40         21.50
# ADS.DE                     251.39         336.25        231.55
# ADYEN.AS                  2129.11        2835.00       1619.00
# AI.PA                      153.01         160.04        124.25
# AIR.PA                     110.23         121.10         89.54
# ALV.DE                     212.59         230.05        182.52
# ASML.AS                    661.02         777.50        422.25
# BAS.DE                      63.20          72.88         57.06
# BAYN.DE                     48.53          57.73         43.90
# BBVA.MC                      5.33           6.29          4.22
# BMW.DE                      91.75         100.42         68.87
# BN.PA                       54.99          65.30         51.42
# BNP.PA                      60.74          67.15         43.50
# CRG.IR                      45.32          48.18         35.12
# CS.PA                       26.56          28.75         18.88
# DAI.DE                      71.47          91.63         64.12
# DB1.DE                     147.44         163.35        130.10
# DG.PA                       91.76         100.82         82.94
# DPW.DE                      54.00          61.38         40.68
# DTE.DE                      16.15          18.92         14.60
# EL.PA                      179.01         195.00        128.35
# ENEL.MI                      6.83           8.77          6.47
# ENI.MI                      12.59          13.84          8.57
# FLTR.IR                    131.19         198.60        116.40
# IBE.MC                      10.03          11.74          8.59
# IFX.DE                      39.01          43.85         29.79
# INGA.AS                     12.65          13.74          7.70
# ISP.MI                     2.3701         2.7850        2.0605
# ITX.MC                      28.03          32.85         25.02
# KER.PA                     689.08         798.00        513.30
# KNEBV.HE                    60.41          73.86         54.22
# LIN.DE                     291.21         309.35        201.80
# MC.PA                      707.42         758.50        518.70
# MUV2.DE                    261.42         282.25        215.25
# OR.PA                      401.67         433.65        302.20
# PHIA.AS                     30.91          50.98         27.72
# PRX.AS                      72.44         110.00         65.71
# RI.PA                      204.34         217.20        156.10
# SAF.PA                     106.57         127.74         96.17
# SAN.MC                     2.9513         3.5090        2.6530
# SAN.PA                      88.53          95.16         74.92
# SAP.DE                     119.37         129.74        100.46
# SIE.DE                     147.40         157.96        124.96
# STLA.MI                     17.10          19.35         12.37
# SU.PA                      163.19         178.78        121.40
# TTE.PA                      46.18          52.49         33.91
# UMG.AS                      23.90          27.96         20.64
# VNA.DE                      48.84          60.96         46.28
# VOW.DE                     264.31         357.40        179.60
#
# Attribute 52-Week Change 3 Avg Vol (10 day) 3 Avg Vol (3 month) 3  ...  \
# Ticker                                                             ...
# ABI.BR               0.74%              1.88M               1.69M  ...
# AD.AS               23.78%              3.48M               2.86M  ...
# ADS.DE             -13.02%            855.87k             640.53k  ...
# ADYEN.AS           -14.65%             113.4k              77.81k  ...
# AI.PA               10.38%            794.77k             711.76k  ...
# AIR.PA              18.93%              1.77M               1.63M  ...
# ALV.DE              15.27%              1.09M             896.51k  ...
# ASML.AS             22.84%              1.09M             827.76k  ...
# BAS.DE               0.18%              3.64M               3.01M  ...
# BAYN.DE             -4.27%              3.53M               3.07M  ...
# BBVA.MC             26.87%             27.17M              23.39M  ...
# BMW.DE              34.31%              1.38M                1.2M  ...
# BN.PA                3.65%              1.76M               1.55M  ...
# BNP.PA              44.24%               4.1M                3.2M  ...
# CRG.IR              27.78%              2.48M               1.76M  ...
# CS.PA               46.78%              6.24M                5.5M  ...
# DAI.DE               5.66%              2.62M               3.24M  ...
# DB1.DE              13.91%            590.39k             456.37k  ...
# DG.PA               12.33%              1.38M               1.27M  ...
# DPW.DE              26.75%              2.87M               2.31M  ...
# DTE.DE              15.17%             13.04M              10.34M  ...
# EL.PA               31.22%            664.31k              539.4k  ...
# ENEL.MI            -20.25%             26.92M              26.92M  ...
# ENI.MI              53.07%             19.19M              15.55M  ...
# FLTR.IR            -22.55%            443.94k             371.37k  ...
# IBE.MC             -10.39%             16.08M              13.86M  ...
# IFX.DE              -1.75%              6.75M               4.34M  ...
# INGA.AS             68.58%             17.65M              14.99M  ...
# ISP.MI              30.53%            129.15M              90.28M  ...
# ITX.MC              -0.58%              3.54M               4.15M  ...
# KER.PA              20.55%            203.06k             188.41k  ...
# KNEBV.HE           -15.80%            773.97k             745.41k  ...
# LIN.DE              28.44%            888.37k             714.68k  ...
# MC.PA               34.82%            521.78k             409.83k  ...
# MUV2.DE             18.03%            376.07k             322.45k  ...
# OR.PA               20.86%             501.2k             374.67k  ...
# PHIA.AS            -38.30%              3.99M               4.07M  ...
# PRX.AS             -29.97%              2.34M               2.22M  ...
# RI.PA               18.48%            433.06k             365.14k  ...
# SAF.PA              -4.30%            999.49k              902.1k  ...
# SAN.MC              15.96%             60.84M              53.16M  ...
# SAN.PA              13.02%              2.67M                  2M  ...
# SAP.DE               0.13%              3.52M               2.15M  ...
# SIE.DE               3.32%              1.89M               1.43M  ...
# STLA.MI             34.61%              15.3M              12.01M  ...
# SU.PA               19.63%              1.14M             893.17k  ...
# TTE.PA              41.30%              8.83M               6.97M  ...
# UMG.AS             -13.07%              2.76M               2.49M  ...
# VNA.DE              -8.54%              2.01M               2.37M  ...
# VOW.DE              38.44%             48.19k              48.77k  ...
#
# Attribute Shares Short 4 Short % of Float 4 Short % of Shares Outstanding 4  \
# Ticker
# ABI.BR               NaN                NaN                             NaN
# AD.AS                NaN                NaN                             NaN
# ADS.DE               NaN                NaN                             NaN
# ADYEN.AS             NaN                NaN                             NaN
# AI.PA                NaN                NaN                             NaN
# AIR.PA               NaN                NaN                             NaN
# ALV.DE               NaN                NaN                             NaN
# ASML.AS              NaN                NaN                             NaN
# BAS.DE               NaN                NaN                             NaN
# BAYN.DE              NaN                NaN                             NaN
# BBVA.MC              NaN                NaN                             NaN
# BMW.DE               NaN                NaN                             NaN
# BN.PA                NaN                NaN                             NaN
# BNP.PA               NaN                NaN                             NaN
# CRG.IR               NaN                NaN                             NaN
# CS.PA                NaN                NaN                             NaN
# DAI.DE               NaN                NaN                             NaN
# DB1.DE               NaN                NaN                             NaN
# DG.PA                NaN                NaN                             NaN
# DPW.DE               NaN                NaN                             NaN
# DTE.DE               NaN                NaN                             NaN
# EL.PA                NaN                NaN                             NaN
# ENEL.MI              NaN                NaN                             NaN
# ENI.MI               NaN                NaN                             NaN
# FLTR.IR              NaN                NaN                             NaN
# IBE.MC               NaN                NaN                             NaN
# IFX.DE               NaN                NaN                             NaN
# INGA.AS              NaN                NaN                             NaN
# ISP.MI               NaN                NaN                             NaN
# ITX.MC               NaN                NaN                             NaN
# KER.PA               NaN                NaN                             NaN
# KNEBV.HE             NaN                NaN                             NaN
# LIN.DE               NaN                NaN                             NaN
# MC.PA                NaN                NaN                             NaN
# MUV2.DE              NaN                NaN                             NaN
# OR.PA                NaN                NaN                             NaN
# PHIA.AS              NaN                NaN                             NaN
# PRX.AS               NaN                NaN                             NaN
# RI.PA                NaN                NaN                             NaN
# SAF.PA               NaN                NaN                             NaN
# SAN.MC               NaN                NaN                             NaN
# SAN.PA               NaN                NaN                             NaN
# SAP.DE               NaN                NaN                             NaN
# SIE.DE               NaN                NaN                             NaN
# STLA.MI              NaN                NaN                             NaN
# SU.PA                NaN                NaN                             NaN
# TTE.PA               NaN                NaN                             NaN
# UMG.AS               NaN                NaN                             NaN
# VNA.DE               NaN                NaN                             NaN
# VOW.DE               NaN                NaN                             NaN
#
# Attribute Short Ratio 4 Total Cash (mrq) Total Cash Per Share (mrq)  \
# Ticker
# ABI.BR              NaN            7.08B                       3.57
# AD.AS               NaN            5.17B                       5.06
# ADS.DE              NaN            4.43B                      22.95
# ADYEN.AS            NaN            3.34B                     109.83
# AI.PA               NaN            1.39B                       2.94
# AIR.PA              NaN           16.65B                      21.19
# ALV.DE              NaN           21.94B                      52.89
# ASML.AS             NaN            7.59B                      18.77
# BAS.DE              NaN             3.1B                       3.37
# BAYN.DE             NaN            8.22B                       8.37
# BBVA.MC             NaN          191.29B                      28.53
# BMW.DE              NaN           14.33B                      21.72
# BN.PA               NaN            6.29B                       9.66
# BNP.PA              NaN            1.21T                     969.91
# CRG.IR              NaN            6.29B                       8.02
# CS.PA               NaN           26.79B                      11.22
# DAI.DE              NaN           21.22B                      19.84
# DB1.DE              NaN           20.88B                     113.79
# DG.PA               NaN             9.3B                      16.15
# DPW.DE              NaN            5.91B                       4.81
# DTE.DE              NaN            6.34B                       1.32
# EL.PA               NaN            9.44B                      21.43
# ENEL.MI             NaN           10.44B                       1.03
# ENI.MI              NaN           13.83B                       3.87
# FLTR.IR             NaN           643.1M                       3.68
# IBE.MC              NaN            5.42B                       0.85
# IFX.DE              NaN            4.28B                       3.29
# INGA.AS             NaN          159.44B                      42.23
# ISP.MI              NaN           87.14B                       4.71
# ITX.MC              NaN            9.58B                       3.08
# KER.PA              NaN            4.79B                      38.42
# KNEBV.HE            NaN            2.89B                       5.57
# LIN.DE              NaN             4.7B                       9.17
# MC.PA               NaN            10.6B                      21.04
# MUV2.DE             NaN            7.21B                      51.58
# OR.PA               NaN            4.82B                       8.65
# PHIA.AS             NaN             2.3B                       2.65
# PRX.AS              NaN           13.68B                       8.67
# RI.PA               NaN            2.08B                       7.96
# SAF.PA              NaN            4.06B                       9.52
# SAN.MC              NaN          366.08B                      21.45
# SAN.PA              NaN              NaN                        NaN
# SAP.DE              NaN           11.66B                       9.88
# SIE.DE              NaN           10.68B                      13.31
# STLA.MI             NaN           41.67B                      13.31
# SU.PA               NaN            3.57B                       6.44
# TTE.PA              NaN           32.88B                      12.45
# UMG.AS              NaN             936M                       0.52
# VNA.DE              NaN            2.17B                       3.78
# VOW.DE              NaN           40.66B                      81.11
#
# Attribute Total Debt (mrq) Total Debt/Equity (mrq)  \
# Ticker
# ABI.BR              90.64B                  113.92
# AD.AS               19.17B                  146.51
# ADS.DE               5.27B                   66.01
# ADYEN.AS           128.36M                    8.94
# AI.PA               14.61B                   74.66
# AIR.PA              14.92B                  169.50
# ALV.DE              36.25B                   42.47
# ASML.AS              4.08B                   40.19
# BAS.DE              19.78B                   48.70
# BAYN.DE             41.77B                  133.55
# BBVA.MC             55.76B                     NaN
# BMW.DE              104.5B                  144.44
# BN.PA               17.66B                  105.75
# BNP.PA             520.91B                     NaN
# CRG.IR              12.47B                   62.14
# CS.PA               55.92B                   69.77
# DAI.DE             130.71B                  173.66
# DB1.DE               4.79B                   65.89
# DG.PA               30.66B                  123.77
# DPW.DE              19.42B                  110.06
# DTE.DE             141.73B                  179.72
# EL.PA               11.41B                   33.20
# ENEL.MI             67.58B                  153.31
# ENI.MI              31.42B                   78.01
# FLTR.IR              3.48B                   32.48
# IBE.MC              42.07B                   80.79
# IFX.DE               6.99B                   58.06
# INGA.AS            179.54B                     NaN
# ISP.MI             312.42B                     NaN
# ITX.MC               5.86B                   39.20
# KER.PA               9.82B                   76.89
# KNEBV.HE            552.2M                   17.26
# LIN.DE              16.73B                   36.57
# MC.PA               34.54B                   70.63
# MUV2.DE              5.29B                   17.60
# OR.PA                2.45B                    8.27
# PHIA.AS              6.98B                   48.22
# PRX.AS              10.81B                   19.78
# RI.PA                9.59B                   63.65
# SAF.PA               6.88B                   51.15
# SAN.MC             305.44B                     NaN
# SAN.PA                 NaN                     NaN
# SAP.DE              15.57B                   37.41
# SIE.DE               48.7B                   98.83
# STLA.MI             31.36B                   67.10
# SU.PA               11.45B                   45.16
# TTE.PA              67.78B                   59.87
# UMG.AS               3.44B                  231.07
# VNA.DE               46.7B                  162.57
# VOW.DE             205.86B                  145.32
#
# Attribute Trailing Annual Dividend Rate 3 Trailing Annual Dividend Yield 3
# Ticker
# ABI.BR                               0.00                            0.00%
# AD.AS                                0.83                            2.88%
# ADS.DE                               3.00                            1.24%
# ADYEN.AS                             0.00                            0.00%
# AI.PA                                2.75                            1.82%
# AIR.PA                               0.00                            0.00%
# ALV.DE                               0.00                            0.00%
# ASML.AS                              5.50                            0.96%
# BAS.DE                               3.30                            4.89%
# BAYN.DE                              2.00                            3.78%
# BBVA.MC                              0.31                            5.44%
# BMW.DE                               1.90                            2.03%
# BN.PA                                1.94                            3.52%
# BNP.PA                               1.11                            1.74%
# CRG.IR                               1.16                            2.54%
# CS.PA                                1.43                            5.06%
# DAI.DE                               1.35                            1.92%
# DB1.DE                               3.00                            1.94%
# DG.PA                                0.00                            0.00%
# DPW.DE                               1.35                            2.52%
# DTE.DE                               0.60                            3.47%
# EL.PA                                1.08                            0.63%
# ENEL.MI                              0.37                            5.50%
# ENI.MI                               0.67                            5.04%
# FLTR.IR                              0.00                            0.00%
# IBE.MC                               0.42                            4.24%
# IFX.DE                               0.27                            0.78%
# INGA.AS                              0.62                            4.69%
# ISP.MI                               0.21                            7.59%
# ITX.MC                               0.00                            0.00%
# KER.PA                               9.00                            1.36%
# KNEBV.HE                             1.75                            3.12%
# LIN.DE                               4.14                            1.50%
# MC.PA                               10.00                            1.41%
# MUV2.DE                              9.80                            3.58%
# OR.PA                                4.00                            1.07%
# PHIA.AS                              0.85                            2.95%
# PRX.AS                               0.16                            0.23%
# RI.PA                                3.12                            1.62%
# SAF.PA                               0.43                            0.40%
# SAN.MC                               0.00                            0.00%
# SAN.PA                               3.20                            3.51%
# SAP.DE                               0.00                            0.00%
# SIE.DE                               4.00                            2.92%
# STLA.MI                              0.00                            0.00%
# SU.PA                                2.60                            1.74%
# TTE.PA                               3.10                            6.24%
# UMG.AS                               0.20                            0.92%
# VNA.DE                               1.69                            3.37%
# VOW.DE                               4.86                            1.91%
#
# [50 rows x 51 columns]

# %% [markdown]
# The next problem we encounter is that there are a bunch of footnotes in the attribute descriptions. The reason for this is that on the Yahoo Finance website, the attributes may / may not have some additional information attached to them.
#
# However, since we are aiming to create a scheduled graph, we are not really interested in these additional footnotes.
#
# Next step would be to eliminate these footnote numbers.
# In order to do that we need to rename all the colums affeted and subsequently change them from strings into floats

# %%
#df1_wide.rename(columns = {"NAME OF CURRENT ATTRIBUTE W/ FOOTNOTE":"NEW NAME"}, inplace = True)

###.astype 

df1_wide.columns
# Out:
# Index(['Enterprise Value', 'Enterprise Value/EBITDA',
#        'Enterprise Value/Revenue', 'Forward P/E', 'Market Cap (intraday)',
#        'PEG Ratio (5 yr expected)', 'Price/Book (mrq)', 'Price/Sales (ttm)',
#        'Trailing P/E'],
#       dtype='object', name='Attribute')
