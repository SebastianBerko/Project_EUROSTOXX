# %%
# !pip install yahoo_fin
# Out:
# Requirement already satisfied: yahoo_fin in ./opt/anaconda3/lib/python3.8/site-packages (0.8.9.1)
# Requirement already satisfied: requests-html in ./opt/anaconda3/lib/python3.8/site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.8/site-packages (from yahoo_fin) (2.25.1)
# Requirement already satisfied: pandas in ./opt/anaconda3/lib/python3.8/site-packages (from yahoo_fin) (1.2.4)
# Requirement already satisfied: feedparser in ./opt/anaconda3/lib/python3.8/site-packages (from yahoo_fin) (6.0.8)
# Requirement already satisfied: sgmllib3k in ./opt/anaconda3/lib/python3.8/site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in ./opt/anaconda3/lib/python3.8/site-packages (from pandas->yahoo_fin) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in ./opt/anaconda3/lib/python3.8/site-packages (from pandas->yahoo_fin) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in ./opt/anaconda3/lib/python3.8/site-packages (from pandas->yahoo_fin) (1.20.1)
# Requirement already satisfied: six>=1.5 in ./opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->yahoo_fin) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->yahoo_fin) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->yahoo_fin) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->yahoo_fin) (4.0.0)
# Requirement already satisfied: pyquery in ./opt/anaconda3/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: pyppeteer>=0.0.14 in ./opt/anaconda3/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.2.6)
# Requirement already satisfied: w3lib in ./opt/anaconda3/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.22.0)
# Requirement already satisfied: parse in ./opt/anaconda3/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: fake-useragent in ./opt/anaconda3/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.1.11)
# Requirement already satisfied: bs4 in ./opt/anaconda3/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: importlib-metadata>=1.4 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.10.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.59.0)
# Requirement already satisfied: websockets<10.0,>=9.1 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (9.1)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: zipp>=0.5 in ./opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.4.1)
# Requirement already satisfied: beautifulsoup4 in ./opt/anaconda3/lib/python3.8/site-packages (from bs4->requests-html->yahoo_fin) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in ./opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.2.1)
# Requirement already satisfied: lxml>=2.1 in ./opt/anaconda3/lib/python3.8/site-packages (from pyquery->requests-html->yahoo_fin) (4.6.3)
# Requirement already satisfied: cssselect>0.7.9 in ./opt/anaconda3/lib/python3.8/site-packages (from pyquery->requests-html->yahoo_fin) (1.1.0)

# %%
# !pip install requests_html
# Out:
# Requirement already satisfied: requests_html in ./opt/anaconda3/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (2.25.1)
# Requirement already satisfied: w3lib in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (1.22.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (0.2.6)
# Requirement already satisfied: bs4 in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (0.0.1)
# Requirement already satisfied: pyquery in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (1.4.3)
# Requirement already satisfied: parse in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (1.19.0)
# Requirement already satisfied: fake-useragent in ./opt/anaconda3/lib/python3.8/site-packages (from requests_html) (0.1.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (4.59.0)
# Requirement already satisfied: importlib-metadata>=1.4 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (3.10.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.4)
# Requirement already satisfied: websockets<10.0,>=9.1 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (9.1)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in ./opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: zipp>=0.5 in ./opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.4.1)
# Requirement already satisfied: beautifulsoup4 in ./opt/anaconda3/lib/python3.8/site-packages (from bs4->requests_html) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in ./opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->bs4->requests_html) (2.2.1)
# Requirement already satisfied: lxml>=2.1 in ./opt/anaconda3/lib/python3.8/site-packages (from pyquery->requests_html) (4.6.3)
# Requirement already satisfied: cssselect>0.7.9 in ./opt/anaconda3/lib/python3.8/site-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->requests_html) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->requests_html) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->requests_html) (2.10)
# Requirement already satisfied: six>=1.4.1 in ./opt/anaconda3/lib/python3.8/site-packages (from w3lib->requests_html) (1.15.0)

# %% [markdown]
# **We found the below method of downloading Yahoo Finance information from the statistics page on the internet and it seems to work. Alternativly, one could go into each of the ticker codes of Yahoo Finance page**

# %%
import yahoo_fin.stock_info as si #Get data
import pandas as pd #Data manipulation
from tqdm import tqdm #Make a progress bar because that's cool...
import requests # to get data
from bs4 import BeautifulSoup # to parse external data
from requests_html import HTMLSession
import matplotlib.pyplot as plt

# %%
scrEURSTX = requests.get('https://en.wikipedia.org/wiki/EURO_STOXX_50')
soupEURSTX = BeautifulSoup(scrEURSTX.text, 'lxml')
tableEURSTX = soupEURSTX.find(text="Ticker").find_parent("table").find('tbody').findAll('tr')[1:]

EURSTX_companies = pd.DataFrame()
for row in tableEURSTX:
    ticker = row.findAll('td')[0].text.strip()
    title = row.findAll('td')[2].text.strip()
    industry = row.findAll('td')[5].text.strip()
    row_ = pd.Series({"Ticker":ticker, "Name": title, "Industry":industry})
    EURSTX_companies = pd.concat([EURSTX_companies, row_], axis=1, ignore_index = True)
    
EURSTX_companies = EURSTX_companies.T
EURSTX_ticker = EURSTX_companies.iloc[:,0]
EURSTX_companies
EURSTX_ticker
# Out:
# 0       ADS.DE
# 1     ADYEN.AS
# 2        AD.AS
# 3        AI.PA
# 4       AIR.PA
# 5       ALV.DE
# 6       ABI.BR
# 7      ASML.AS
# 8        CS.PA
# 9       BAS.DE
# 10     BAYN.DE
# 11     BBVA.MC
# 12      SAN.MC
# 13      BMW.DE
# 14      BNP.PA
# 15      CRG.IR
# 16      DAI.DE
# 17       BN.PA
# 18      DB1.DE
# 19      DPW.DE
# 20      DTE.DE
# 21     ENEL.MI
# 22      ENI.MI
# 23       EL.PA
# 24     FLTR.IR
# 25      IBE.MC
# 26      ITX.MC
# 27      IFX.DE
# 28     INGA.AS
# 29      ISP.MI
# 30      KER.PA
# 31    KNEBV.HE
# 32       OR.PA
# 33      LIN.DE
# 34       MC.PA
# 35     MUV2.DE
# 36       RI.PA
# 37     PHIA.AS
# 38      PRX.AS
# 39      SAF.PA
# 40      SAN.PA
# 41      SAP.DE
# 42       SU.PA
# 43      SIE.DE
# 44     STLA.MI
# 45      TTE.PA
# 46      UMG.AS
# 47       DG.PA
# 48      VOW.DE
# 49      VNA.DE
# Name: Ticker, dtype: object

# %%
companies = ["ADS.DE", "ADYEN.AS", "AD.AS", "AI.PA", "AIR.PA", "ALV.DE", "ABI.BR", "ASML.AS", "CS.PA", "BAS.DE", "BAYN.DE", "BBVA.MC", "SAN.MC", "BMW.DE", "BNP.PA", "CRG.IR", "DAI.DE", "BN.PA", "DB1.DE", "DPW.DE", "DTE.DE", "ENEL.MI", "ENI.MI", "CS.PA", "EL.PA", "FLTR.IR", "IBE.MC", "ITX.MC", "IFX.DE", "INGA.AS", "ISP.MI", "KER.PA", "KNEBV.HE", "OR.PA", "LIN.DE", "MC.PA", "MUV2.DE", "RI.PA", "PHIA.AS", "PRX.AS", "SAF.PA", "SAN.PA", "SAP.DE", "SU.PA", "SIE.DE", "STLA.MI", "TTE.PA", "UMG.AS", "DG.PA", "VOW.DE", "VNA.DE"]

# %%
ticker_stats = {}
for ticker in companies:
    temp = si.get_stats_valuation(ticker)
    temp = temp.iloc[:,:2]
    #temp.iloc[:,:2] creates to columns
    temp.columns = ["Attribute", "Recent"]
    #We want the name of the data and then the data itself
 
    ticker_stats[ticker] = temp
    #Where to get


# combine all the stats valuation tables into a single data frame
df1 = pd.concat(ticker_stats)
#Adding the data together by concatenating.
df1 = df1.reset_index()
#Adding a sequantial index and using the Ticker as the index 

del df1["level_1"]
#dropping level 1 of the multi-index

# update column names
df1.columns = ["Ticker", "Attribute", "Recent"]

# Same, but for more data
ticker_extra_stats = {}
for ticker in tqdm(companies):
    ticker_extra_stats[ticker] = si.get_stats(ticker)
    

df2 = pd.concat(ticker_extra_stats)

df2 = df2.reset_index()

del df2["level_1"]

df2.columns = ["Ticker", "Attribute", "Value"]
# Out:
# 100%|██████████| 51/51 [00:57<00:00,  1.13s/it]

# %%
print(df1)
# Out:
#      Ticker                  Attribute  Recent
# 0    ADS.DE      Market Cap (intraday)  49.08B
# 1    ADS.DE           Enterprise Value  49.96B
# 2    ADS.DE               Trailing P/E   32.93
# 3    ADS.DE                Forward P/E   26.25
# 4    ADS.DE  PEG Ratio (5 yr expected)    0.62
# ..      ...                        ...     ...
# 445  VNA.DE  PEG Ratio (5 yr expected)     NaN
# 446  VNA.DE          Price/Sales (ttm)    9.45
# 447  VNA.DE           Price/Book (mrq)    1.12
# 448  VNA.DE   Enterprise Value/Revenue    8.55
# 449  VNA.DE    Enterprise Value/EBITDA    3.17
#
# [450 rows x 3 columns]

# %%
print(df2)
# Out:
#       Ticker                     Attribute    Value
# 0     ADS.DE             Beta (5Y Monthly)     0.89
# 1     ADS.DE              52-Week Change 3  -14.97%
# 2     ADS.DE       S&P500 52-Week Change 3   26.83%
# 3     ADS.DE                52 Week High 3   336.25
# 4     ADS.DE                 52 Week Low 3   242.95
# ...      ...                           ...      ...
# 2545  VNA.DE       Total Debt/Equity (mrq)   162.57
# 2546  VNA.DE           Current Ratio (mrq)     0.39
# 2547  VNA.DE    Book Value Per Share (mrq)    47.85
# 2548  VNA.DE     Operating Cash Flow (ttm)    1.44B
# 2549  VNA.DE  Levered Free Cash Flow (ttm)    8.66B
#
# [2550 rows x 3 columns]

# %% [markdown]
# **Now we simply need to format the data into a format which is usable in relation to the graph we wish to display:**
#
# At the moment, we have the data in very few columns and many rows. Essentially, every ticker is repeated for every attribute. We now wish to change this such that the ticker is displayed once in a row and all the attributed on a column name.

# %%
# Convert from long dataframe to wide dataframe using the pivot() method.
df1_wide = df1.pivot(index = "Ticker", columns="Attribute", values="Recent")
df2_wide = df2.pivot(index = "Ticker", columns="Attribute", values="Value")

# %%
print(df1_wide)
# Out:
# Attribute Enterprise Value Enterprise Value/EBITDA Enterprise Value/Revenue  \
# Ticker
# ABI.BR             162.65B                   12.01                     3.08
# AD.AS               29.88B                    5.49                     0.40
# ADS.DE              49.96B                   14.94                     2.21
# ADYEN.AS            71.68B                  143.83                    15.46
# AI.PA               86.20B                   14.56                     4.09
# AIR.PA              79.23B                   10.08                     1.44
# ALV.DE              97.13B                     NaN                     0.86
# ASML.AS            282.78B                   42.24                    15.82
# BAS.DE              71.63B                    6.25                     0.96
# BAYN.DE             75.46B                   10.62                     1.81
# BBVA.MC                NaN                     NaN                      NaN
# BMW.DE             127.17B                    5.73                     1.13
# BN.PA               44.70B                   12.50                     1.92
# BNP.PA                 NaN                     NaN                      NaN
# CRG.IR              39.74B                    9.17                     1.35
# CS.PA               56.47B                     NaN                     0.50
# DAI.DE             182.28B                    7.45                     1.09
# DB1.DE             -60.68B                  -30.37                   -14.52
# DG.PA               69.37B                    9.98                     1.44
# DPW.DE              78.62B                    7.15                     1.07
# DTE.DE             210.47B                    4.86                     1.96
# EL.PA               83.25B                   20.03                     4.91
# ENEL.MI             92.00B                    6.14                     1.18
# ENI.MI              59.81B                    3.72                     0.97
# FLTR.IR             25.73B                   25.08                     4.34
# IBE.MC              97.72B                    9.29                     2.65
# IFX.DE              55.03B                   18.42                     4.98
# INGA.AS                NaN                     NaN                      NaN
# ISP.MI                 NaN                     NaN                      NaN
# ITX.MC              86.39B                   13.93                     3.55
# KER.PA              91.61B                   14.90                     5.81
# KNEBV.HE            29.66B                   18.58                     2.86
# LIN.DE             162.24B                   16.73                     5.45
# MC.PA              387.39B                   19.32                     7.05
# MUV2.DE             33.79B                     NaN                     0.50
# OR.PA              232.44B                   30.01                     7.72
# PHIA.AS             34.53B                   26.67                     1.90
# PRX.AS             225.07B                   10.89                    37.46
# RI.PA               62.17B                   23.62                     7.05
# SAF.PA              47.11B                   13.01                     3.25
# SAN.MC                 NaN                     NaN                      NaN
# SAN.PA             120.55B                   10.82                     3.21
# SAP.DE             146.87B                   14.39                     5.36
# SIE.DE             153.67B                   13.91                     2.50
# STLA.MI             41.89B                    2.55                     0.33
# SU.PA              100.76B                   19.38                     3.68
# TTE.PA             146.01B                    4.40                     0.90
# UMG.AS              48.20B                   32.75                     6.18
# VNA.DE              27.54B                    3.17                     8.55
# VOW.DE             235.54B                    4.43                     0.93
#
# Attribute Forward P/E Market Cap (intraday) PEG Ratio (5 yr expected)  \
# Ticker
# ABI.BR          17.99                88.66B                      6.35
# AD.AS           13.91                30.78B                     18.07
# ADS.DE          26.25                49.08B                      0.62
# ADYEN.AS       121.95                74.88B                      3.58
# AI.PA           25.00                73.04B                      2.48
# AIR.PA          20.53                82.97B                      1.11
# ALV.DE           9.20                82.81B                      0.98
# ASML.AS         40.65               283.13B                      1.80
# BAS.DE          10.14                54.95B                      0.71
# BAYN.DE          6.92                45.79B                      2.67
# BBVA.MC          6.79                33.82B                      0.39
# BMW.DE           5.99                58.24B                      0.24
# BN.PA           16.26                33.83B                      4.62
# BNP.PA           8.24                69.94B                      0.88
# CRG.IR          14.06                34.29B                      1.18
# CS.PA            8.48                60.96B                      1.25
# DAI.DE           6.14                79.43B                      0.30
# DB1.DE          19.42                25.46B                      2.41
# DG.PA           13.64                48.63B                      0.52
# DPW.DE          13.74                66.07B                      1.19
# DTE.DE          11.79                79.05B                      1.13
# EL.PA           30.21                81.28B                       NaN
# ENEL.MI         11.75                67.98B                      1.69
# ENI.MI           7.42                43.25B                       NaN
# FLTR.IR         29.85                22.60B                       NaN
# IBE.MC          14.99                61.07B                      2.08
# IFX.DE          24.75                52.04B                      1.43
# INGA.AS          9.56                46.63B                      0.57
# ISP.MI           9.23                42.91B                      0.23
# ITX.MC          22.17                88.46B                      0.61
# KER.PA          23.64                86.91B                      1.51
# KNEBV.HE        26.45                31.61B                      3.21
# LIN.DE          28.49               151.59B                      2.31
# MC.PA           29.76               357.56B                      1.28
# MUV2.DE         10.68                34.76B                      0.46
# OR.PA           45.45               234.81B                      4.61
# PHIA.AS         15.70                27.71B                      2.42
# PRX.AS          12.69               227.55B                       NaN
# RI.PA           29.07                54.65B                      2.45
# SAF.PA          25.19                44.31B                      0.78
# SAN.MC           5.51                46.04B                      0.40
# SAN.PA          12.12               108.62B                      3.35
# SAP.DE          19.84               140.82B                      2.35
# SIE.DE          17.76               120.73B                      1.21
# STLA.MI          4.78                52.20B                      0.29
# SU.PA           24.33                92.90B                      2.22
# TTE.PA           8.48               115.55B                       NaN
# UMG.AS          31.45                45.56B                       NaN
# VNA.DE          19.12                30.88B                       NaN
# VOW.DE           8.43               117.75B                      0.85
#
# Attribute Price/Book (mrq) Price/Sales (ttm) Trailing P/E
# Ticker
# ABI.BR                1.47              2.20        39.93
# AD.AS                 2.35              0.42        19.57
# ADS.DE                6.91              2.19        32.93
# ADYEN.AS             52.13             16.00       201.50
# AI.PA                 3.83              3.48        28.25
# AIR.PA                9.44              1.51        19.81
# ALV.DE                1.01              0.73        12.29
# ASML.AS              24.61             15.84        51.89
# BAS.DE                1.40              0.74        10.23
# BAYN.DE               1.51              1.10        22.83
# BBVA.MC               0.75              1.41         9.29
# BMW.DE                0.83              0.53         5.01
# BN.PA                 2.04              1.48        17.27
# BNP.PA                0.60              1.26         8.50
# CRG.IR                1.99              1.35        26.31
# CS.PA                 0.89              0.54        10.94
# DAI.DE                1.08              0.47         6.87
# DB1.DE                3.50              6.09        21.99
# DG.PA                 2.28              1.01        21.80
# DPW.DE                4.13              0.92        14.57
# DTE.DE                1.92              0.70        13.91
# EL.PA                 2.40              4.83        60.50
# ENEL.MI               2.23              0.89        31.86
# ENI.MI                1.08              0.71        30.52
# FLTR.IR               1.81              3.13          NaN
# IBE.MC                1.36              1.70        19.21
# IFX.DE                4.56              4.71        45.44
# INGA.AS               0.83              2.67        12.24
# ISP.MI                0.64              1.28        70.30
# ITX.MC                6.49              3.64        34.42
# KER.PA                6.94              5.55        26.22
# KNEBV.HE             10.88              3.07        31.13
# LIN.DE                3.86              5.88        49.11
# MC.PA                 8.68              6.52        37.83
# MUV2.DE               1.16              0.51        15.31
# OR.PA                 7.92              7.86        57.68
# PHIA.AS               2.32              1.55        26.24
# PRX.AS                4.72             21.80         6.45
# RI.PA                 3.69              6.24        42.16
# SAF.PA                3.40              3.17        33.17
# SAN.MC                0.54              1.08         8.39
# SAN.PA                1.72              2.90        18.80
# SAP.DE                4.00              5.14        24.72
# SIE.DE                2.87              2.00        24.24
# STLA.MI               1.11              0.31         4.62
# SU.PA                 4.29              3.41        32.08
# TTE.PA                1.19              0.84        12.26
# UMG.AS               30.64              5.84        42.58
# VNA.DE                1.12              9.45         5.84
# VOW.DE                0.58              0.54         7.69

# %%
print(df2_wide)
# Out:
# Attribute % Held by Insiders 1 % Held by Institutions 1  \
# Ticker
# ABI.BR                  48.74%                   14.10%
# AD.AS                    0.05%                   52.76%
# ADS.DE                  10.29%                   52.69%
# ADYEN.AS                23.66%                   61.73%
# AI.PA                    2.61%                   30.06%
# AIR.PA                  25.84%                   31.71%
# ALV.DE                   0.00%                   40.23%
# ASML.AS                  0.01%                   56.22%
# BAS.DE                   0.00%                   29.19%
# BAYN.DE                  0.00%                   38.37%
# BBVA.MC                  0.02%                   35.06%
# BMW.DE                  46.74%                   21.37%
# BN.PA                    2.65%                   55.30%
# BNP.PA                  13.20%                   45.77%
# CRG.IR                   0.05%                   53.32%
# CS.PA                   18.69%                   40.22%
# DAI.DE                  18.64%                   34.01%
# DB1.DE                   0.00%                   60.59%
# DG.PA                    8.94%                   37.72%
# DPW.DE                  20.49%                   34.79%
# DTE.DE                  18.36%                   42.38%
# EL.PA                   35.99%                   26.99%
# ENEL.MI                 23.58%                   38.25%
# ENI.MI                  31.33%                   17.93%
# FLTR.IR                  3.18%                   61.68%
# IBE.MC                   0.22%                   42.77%
# IFX.DE                   0.00%                   57.99%
# INGA.AS                  0.00%                   52.04%
# ISP.MI                   4.73%                   40.69%
# ITX.MC                  64.35%                   15.46%
# KER.PA                  41.71%                   27.00%
# KNEBV.HE                27.09%                   35.98%
# LIN.DE                   0.20%                   79.87%
# MC.PA                   47.48%                   21.37%
# MUV2.DE                  0.03%                   43.89%
# OR.PA                   54.18%                   14.77%
# PHIA.AS                  0.09%                   53.87%
# PRX.AS                  57.67%                   15.00%
# RI.PA                   24.56%                   50.57%
# SAF.PA                  18.45%                   39.74%
# SAN.MC                   0.73%                   30.90%
# SAN.PA                  11.15%                   54.31%
# SAP.DE                  11.09%                   35.35%
# SIE.DE                   6.00%                   34.94%
# STLA.MI                 26.04%                   51.77%
# SU.PA                    3.77%                   55.77%
# TTE.PA                   6.44%                   47.11%
# UMG.AS                  48.05%                   22.08%
# VNA.DE                   0.00%                   48.58%
# VOW.DE                  73.31%                   18.72%
#
# Attribute 200-Day Moving Average 3 5 Year Average Dividend Yield 4  \
# Ticker
# ABI.BR                       54.84                            3.05
# AD.AS                        26.53                            3.45
# ADS.DE                      286.08                             NaN
# ADYEN.AS                   2266.54                             NaN
# AI.PA                       145.44                            2.19
# AIR.PA                      108.21                             NaN
# ALV.DE                      206.63                            4.53
# ASML.AS                     625.87                            0.84
# BAS.DE                       65.90                            4.69
# BAYN.DE                      50.12                            3.89
# BBVA.MC                       5.27                            4.96
# BMW.DE                       86.22                            4.33
# BN.PA                        58.55                             NaN
# BNP.PA                       54.67                             NaN
# CRG.IR                       42.22                            2.37
# CS.PA                        23.49                             NaN
# DAI.DE                       76.16                            5.09
# DB1.DE                      143.32                            2.19
# DG.PA                        90.69                            2.75
# DPW.DE                       54.51                             NaN
# DTE.DE                       17.09                             NaN
# EL.PA                       159.28                             NaN
# ENEL.MI                       7.67                            4.44
# ENI.MI                       10.89                            6.14
# FLTR.IR                     158.93                             NaN
# IBE.MC                       10.41                            4.27
# IFX.DE                       35.77                            1.16
# INGA.AS                      11.55                             NaN
# ISP.MI                      2.3584                             NaN
# ITX.MC                       30.02                            1.82
# KER.PA                      686.44                            1.54
# KNEBV.HE                     65.94                            3.20
# LIN.DE                      258.35                             NaN
# MC.PA                       653.76                            1.50
# MUV2.DE                     244.90                            4.37
# OR.PA                       377.67                             NaN
# PHIA.AS                      41.19                             NaN
# PRX.AS                       79.51                             NaN
# RI.PA                       186.26                            1.69
# SAF.PA                      114.42                             NaN
# SAN.MC                      3.1274                             NaN
# SAN.PA                       86.20                            3.84
# SAP.DE                      119.20                            1.40
# SIE.DE                      140.62                            3.32
# STLA.MI                      16.33                             NaN
# SU.PA                       142.94                            2.72
# TTE.PA                       39.81                            6.05
# UMG.AS                       24.97                             NaN
# VNA.DE                       54.14                            3.01
# VOW.DE                      281.27                             NaN
#
# Attribute 50-Day Moving Average 3 52 Week High 3 52 Week Low 3  \
# Ticker
# ABI.BR                      51.21          65.86         46.66
# AD.AS                       29.39          31.40         21.50
# ADS.DE                     270.32         336.25        242.95
# ADYEN.AS                  2512.82        2835.00       1643.00
# AI.PA                      149.10         157.40        124.25
# AIR.PA                     108.62         121.00         81.84
# ALV.DE                     201.52         223.50        182.52
# ASML.AS                    702.61         777.50        390.65
# BAS.DE                      61.43          72.88         57.06
# BAYN.DE                     47.72          57.73         43.90
# BBVA.MC                      5.48           6.29          3.74
# BMW.DE                      89.18          96.39         68.21
# BN.PA                       55.45          65.30         51.42
# BNP.PA                      57.99          62.55         39.71
# CRG.IR                      43.32          46.10         33.83
# CS.PA                       25.07          26.35         18.21
# DAI.DE                      80.70          91.63         55.44
# DB1.DE                     144.15         152.65        130.10
# DG.PA                       89.85          96.95         75.38
# DPW.DE                      54.35          61.38         39.61
# DTE.DE                      16.32          18.92         14.60
# EL.PA                      180.87         195.00        116.40
# ENEL.MI                      6.96           9.05          6.47
# ENI.MI                      12.27          12.83          8.15
# FLTR.IR                    142.67         198.60        116.40
# IBE.MC                       9.96          12.57          8.59
# IFX.DE                      40.43          43.85         29.79
# INGA.AS                     12.79          13.74          7.14
# ISP.MI                     2.3560         2.5925        1.7818
# ITX.MC                      30.27          32.85         24.34
# KER.PA                     679.64         798.00        513.30
# KNEBV.HE                    60.19          73.86         55.48
# LIN.DE                     285.69         304.55        199.35
# MC.PA                      696.76         741.60        489.05
# MUV2.DE                    250.83         269.30        215.25
# OR.PA                      405.10         433.65        290.10
# PHIA.AS                     36.03          50.98         29.80
# PRX.AS                      73.78         110.00         65.71
# RI.PA                      205.66         214.50        150.90
# SAF.PA                     110.11         127.74         96.17
# SAN.MC                     3.0554         3.5090        2.3750
# SAN.PA                      86.72          91.14         74.92
# SAP.DE                     122.58         129.74        100.46
# SIE.DE                     146.73         156.98        116.30
# STLA.MI                     16.94          18.74         11.35
# SU.PA                      155.71         170.02        116.45
# TTE.PA                      43.42          45.15         33.91
# UMG.AS                      25.27          27.96         22.55
# VNA.DE                      51.25          60.96         47.11
# VOW.DE                     274.73         357.40        163.60
#
# Attribute 52-Week Change 3 Avg Vol (10 day) 3 Avg Vol (3 month) 3  ...  \
# Ticker                                                             ...
# ABI.BR              -9.13%              1.81M                1.9M  ...
# AD.AS               27.45%              2.64M               2.82M  ...
# ADS.DE             -14.97%            536.08k             602.99k  ...
# ADYEN.AS            14.27%             71.42k              68.37k  ...
# AI.PA               11.78%            695.39k             743.62k  ...
# AIR.PA              20.69%              1.79M               1.68M  ...
# ALV.DE               2.31%            789.13k             847.74k  ...
# ASML.AS             77.23%            795.46k             854.68k  ...
# BAS.DE              -7.33%               2.5M               2.71M  ...
# BAYN.DE             -5.09%              3.34M                2.8M  ...
# BBVA.MC             24.32%             24.06M              34.08M  ...
# BMW.DE              19.16%              1.25M               1.25M  ...
# BN.PA               -0.30%              1.62M               1.63M  ...
# BNP.PA              35.52%              3.07M               3.08M  ...
# CRG.IR              29.13%              1.28M               1.62M  ...
# CS.PA               29.94%              5.79M               5.63M  ...
# DAI.DE              19.09%              4.33M               3.29M  ...
# DB1.DE               4.23%            497.94k             392.54k  ...
# DG.PA                8.47%              1.29M                1.2M  ...
# DPW.DE              36.30%               1.9M               2.64M  ...
# DTE.DE               7.73%              9.95M               9.55M  ...
# EL.PA               44.21%            479.26k              570.9k  ...
# ENEL.MI            -16.87%             27.22M              28.91M  ...
# ENI.MI              41.82%             13.41M              17.69M  ...
# FLTR.IR            -20.08%            343.86k             320.13k  ...
# IBE.MC             -13.30%             17.68M              14.98M  ...
# IFX.DE              26.93%              3.85M               4.13M  ...
# INGA.AS             52.84%             15.68M              16.95M  ...
# ISP.MI              16.60%             73.55M              91.04M  ...
# ITX.MC               8.05%              3.93M               6.45M  ...
# KER.PA              24.46%            166.34k             209.66k  ...
# KNEBV.HE            -5.30%            715.42k             809.67k  ...
# LIN.DE              40.31%            791.01k             696.83k  ...
# MC.PA               44.10%            357.28k             410.16k  ...
# MUV2.DE              4.76%            331.77k             305.54k  ...
# OR.PA               38.60%            327.25k             393.29k  ...
# PHIA.AS            -29.00%              3.85M               3.39M  ...
# PRX.AS             -22.05%              2.19M               2.38M  ...
# RI.PA               34.01%            336.45k             390.48k  ...
# SAF.PA             -11.88%              1.02M             956.36k  ...
# SAN.MC               5.45%             52.82M              66.45M  ...
# SAN.PA              12.15%              2.35M               1.95M  ...
# SAP.DE              18.29%              1.87M               1.95M  ...
# SIE.DE              26.19%              1.22M               1.33M  ...
# STLA.MI             17.99%              9.76M              11.21M  ...
# SU.PA               43.60%            807.86k             894.12k  ...
# TTE.PA              24.58%              6.99M               7.25M  ...
# UMG.AS              -2.91%              4.53M               2.72M  ...
# VNA.DE             -18.36%              2.32M               2.08M  ...
# VOW.DE              52.39%             51.52k              52.44k  ...
#
# Attribute Shares Short 4 Short % of Float 4 Short % of Shares Outstanding 4  \
# Ticker
# ABI.BR               NaN                NaN                             NaN
# AD.AS                NaN                NaN                             NaN
# ADS.DE               NaN                NaN                             NaN
# ADYEN.AS             NaN                NaN                             NaN
# AI.PA                NaN                NaN                             NaN
# AIR.PA               NaN                NaN                             NaN
# ALV.DE               NaN                NaN                             NaN
# ASML.AS              NaN                NaN                             NaN
# BAS.DE               NaN                NaN                             NaN
# BAYN.DE              NaN                NaN                             NaN
# BBVA.MC              NaN                NaN                             NaN
# BMW.DE               NaN                NaN                             NaN
# BN.PA                NaN                NaN                             NaN
# BNP.PA               NaN                NaN                             NaN
# CRG.IR               NaN                NaN                             NaN
# CS.PA                NaN                NaN                             NaN
# DAI.DE               NaN                NaN                             NaN
# DB1.DE               NaN                NaN                             NaN
# DG.PA                NaN                NaN                             NaN
# DPW.DE               NaN                NaN                             NaN
# DTE.DE               NaN                NaN                             NaN
# EL.PA                NaN                NaN                             NaN
# ENEL.MI              NaN                NaN                             NaN
# ENI.MI               NaN                NaN                             NaN
# FLTR.IR              NaN                NaN                             NaN
# IBE.MC               NaN                NaN                             NaN
# IFX.DE               NaN                NaN                             NaN
# INGA.AS              NaN                NaN                             NaN
# ISP.MI               NaN                NaN                             NaN
# ITX.MC               NaN                NaN                             NaN
# KER.PA               NaN                NaN                             NaN
# KNEBV.HE             NaN                NaN                             NaN
# LIN.DE               NaN                NaN                             NaN
# MC.PA                NaN                NaN                             NaN
# MUV2.DE              NaN                NaN                             NaN
# OR.PA                NaN                NaN                             NaN
# PHIA.AS              NaN                NaN                             NaN
# PRX.AS               NaN                NaN                             NaN
# RI.PA                NaN                NaN                             NaN
# SAF.PA               NaN                NaN                             NaN
# SAN.MC               NaN                NaN                             NaN
# SAN.PA               NaN                NaN                             NaN
# SAP.DE               NaN                NaN                             NaN
# SIE.DE               NaN                NaN                             NaN
# STLA.MI              NaN                NaN                             NaN
# SU.PA                NaN                NaN                             NaN
# TTE.PA               NaN                NaN                             NaN
# UMG.AS               NaN                NaN                             NaN
# VNA.DE               NaN                NaN                             NaN
# VOW.DE               NaN                NaN                             NaN
#
# Attribute Short Ratio 4 Total Cash (mrq) Total Cash Per Share (mrq)  \
# Ticker
# ABI.BR              NaN            7.08B                       3.57
# AD.AS               NaN            5.17B                       5.06
# ADS.DE              NaN            4.43B                      22.95
# ADYEN.AS            NaN            3.34B                     109.83
# AI.PA               NaN            1.39B                       2.94
# AIR.PA              NaN           16.65B                      21.19
# ALV.DE              NaN           21.94B                      52.89
# ASML.AS             NaN            4.46B                      10.92
# BAS.DE              NaN             3.1B                       3.37
# BAYN.DE             NaN            8.22B                       8.37
# BBVA.MC             NaN          121.85B                      18.32
# BMW.DE              NaN           14.33B                      21.72
# BN.PA               NaN            6.29B                       9.66
# BNP.PA              NaN            1.21T                     969.91
# CRG.IR              NaN            6.29B                       8.02
# CS.PA               NaN           26.79B                      11.22
# DAI.DE              NaN           21.22B                      19.84
# DB1.DE              NaN           20.88B                     113.79
# DG.PA               NaN           10.45B                      18.25
# DPW.DE              NaN            5.91B                       4.81
# DTE.DE              NaN            6.34B                       1.32
# EL.PA               NaN            9.44B                      21.43
# ENEL.MI             NaN           10.44B                       1.03
# ENI.MI              NaN           13.83B                       3.87
# FLTR.IR             NaN           643.1M                       3.68
# IBE.MC              NaN            5.42B                       0.85
# IFX.DE              NaN            3.92B                       3.01
# INGA.AS             NaN          185.65B                      47.56
# ISP.MI              NaN           87.14B                       4.71
# ITX.MC              NaN            9.58B                       3.08
# KER.PA              NaN            4.79B                      38.42
# KNEBV.HE            NaN             2.5B                       4.83
# LIN.DE              NaN             4.7B                       9.17
# MC.PA               NaN            8.72B                      17.32
# MUV2.DE             NaN            7.21B                      51.58
# OR.PA               NaN            4.82B                       8.65
# PHIA.AS             NaN               1B                        1.1
# PRX.AS              NaN           13.68B                       8.67
# RI.PA               NaN            2.08B                       7.96
# SAF.PA              NaN            4.06B                       9.52
# SAN.MC              NaN           355.2B                       20.5
# SAN.PA              NaN            9.72B                       7.76
# SAP.DE              NaN            7.94B                       6.73
# SIE.DE              NaN           10.68B                      13.31
# STLA.MI             NaN           41.67B                      13.31
# SU.PA               NaN            3.57B                       6.44
# TTE.PA              NaN           32.88B                      12.45
# UMG.AS              NaN             936M                       0.52
# VNA.DE              NaN            2.17B                       3.78
# VOW.DE              NaN           40.66B                      81.11
#
# Attribute Total Debt (mrq) Total Debt/Equity (mrq)  \
# Ticker
# ABI.BR              90.64B                  113.92
# AD.AS               19.17B                  146.51
# ADS.DE               5.27B                   66.01
# ADYEN.AS           128.36M                    8.94
# AI.PA               14.61B                   74.66
# AIR.PA              14.92B                  169.50
# ALV.DE              36.25B                   42.47
# ASML.AS              4.11B                   35.69
# BAS.DE              19.78B                   48.70
# BAYN.DE             41.77B                  133.55
# BBVA.MC            107.76B                     NaN
# BMW.DE              104.5B                  144.44
# BN.PA               17.66B                  105.75
# BNP.PA             520.91B                     NaN
# CRG.IR              12.47B                   62.14
# CS.PA               55.92B                   69.77
# DAI.DE             130.71B                  173.66
# DB1.DE               4.79B                   65.89
# DG.PA               32.09B                  138.13
# DPW.DE              19.42B                  110.06
# DTE.DE             141.73B                  179.72
# EL.PA               11.41B                   33.20
# ENEL.MI             67.58B                  153.31
# ENI.MI              31.42B                   78.01
# FLTR.IR              3.48B                   32.48
# IBE.MC              42.07B                   80.79
# IFX.DE               6.92B                   60.66
# INGA.AS            201.22B                     NaN
# ISP.MI             312.42B                     NaN
# ITX.MC               5.86B                   39.20
# KER.PA               9.82B                   76.89
# KNEBV.HE            554.6M                   18.95
# LIN.DE              16.73B                   36.57
# MC.PA               38.55B                   90.44
# MUV2.DE              5.29B                   17.60
# OR.PA                2.45B                    8.27
# PHIA.AS              7.83B                   65.33
# PRX.AS              10.81B                   19.78
# RI.PA                9.59B                   63.65
# SAF.PA               6.88B                   51.15
# SAN.MC             305.59B                     NaN
# SAN.PA              21.65B                   34.17
# SAP.DE              15.55B                   42.22
# SIE.DE               48.7B                   98.83
# STLA.MI             31.36B                   67.10
# SU.PA               11.45B                   45.16
# TTE.PA              67.78B                   59.87
# UMG.AS               3.44B                  231.07
# VNA.DE               46.7B                  162.57
# VOW.DE             205.86B                  145.32
#
# Attribute Trailing Annual Dividend Rate 3 Trailing Annual Dividend Yield 3
# Ticker
# ABI.BR                               0.61                            1.16%
# AD.AS                                0.83                            2.78%
# ADS.DE                               3.00                            1.20%
# ADYEN.AS                              NaN                              NaN
# AI.PA                                2.75                            1.83%
# AIR.PA                               1.65                            1.49%
# ALV.DE                               9.60                            4.69%
# ASML.AS                              3.35                            0.48%
# BAS.DE                               3.30                            5.50%
# BAYN.DE                              2.00                            4.37%
# BBVA.MC                              0.14                            2.73%
# BMW.DE                               1.90                            2.17%
# BN.PA                                1.94                            3.63%
# BNP.PA                               1.11                            1.87%
# CRG.IR                               1.16                            2.57%
# CS.PA                                1.43                            5.60%
# DAI.DE                               1.35                            1.94%
# DB1.DE                               3.00                            2.08%
# DG.PA                                2.69                            3.01%
# DPW.DE                               1.35                            2.48%
# DTE.DE                               0.60                            3.76%
# EL.PA                                1.08                            0.58%
# ENEL.MI                              0.37                            5.42%
# ENI.MI                               0.67                            5.50%
# FLTR.IR                               NaN                              NaN
# IBE.MC                               0.42                            4.22%
# IFX.DE                               0.27                            0.68%
# INGA.AS                              0.48                            3.97%
# ISP.MI                               0.21                            9.28%
# ITX.MC                               0.22                            0.78%
# KER.PA                               9.00                            1.31%
# KNEBV.HE                             1.75                            2.81%
# LIN.DE                               4.14                            1.40%
# MC.PA                                7.00                            0.98%
# MUV2.DE                              9.80                            3.87%
# OR.PA                                4.00                            0.95%
# PHIA.AS                              0.85                            2.72%
# PRX.AS                               0.16                            0.23%
# RI.PA                                3.12                            1.48%
# SAF.PA                               0.43                            0.41%
# SAN.MC                               0.08                            2.84%
# SAN.PA                               3.20                            3.64%
# SAP.DE                               1.85                            1.51%
# SIE.DE                               4.00                            2.71%
# STLA.MI                               NaN                              NaN
# SU.PA                                2.60                            1.55%
# TTE.PA                               3.10                            6.93%
# UMG.AS                               0.20                            0.82%
# VNA.DE                               1.69                            3.55%
# VOW.DE                               4.86                            1.88%
#
# [50 rows x 51 columns]

# %% [markdown]
# The next problem we encounter is that there are a bunch of footnotes in the attribute descriptions. The reason for this is that on the Yahoo Finance website, the attributes may / may not have some additional information attached to them.
#
# However, since we are aiming to create a scheduled graph, we are not really interested in these additional footnotes.
#
# Next step would be to eliminate these footnote numbers.
# In order to do that we need to rename all the colums affeted and subsequently change them from strings into floats

# %%
#df1_wide.rename(columns = {"NAME OF CURRENT ATTRIBUTE W/ FOOTNOTE":"NEW NAME"}, inplace = True)

###.astype 

df1_wide.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-99aadefe571c> in <module>
#       3 ###.astype
#       4
# ----> 5 df1_wide.columns
#
# NameError: name 'df1_wide' is not defined
